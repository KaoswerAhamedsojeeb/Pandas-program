# %%
import pandas as pd

# %%
df = pd.read_csv("annual_data.csv")
# showing the data from the start position
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2023                     Level 1                99999       All industries
# 1  2023                     Level 1                99999       All industries
# 2  2023                     Level 1                99999       All industries
# 3  2023                     Level 1                99999       All industries
# 4  2023                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
# Tail function is used to show the data frem the end

df.tail(10) # here the last 10 data is showing
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50975  2013                     Level 3                 ZZ11
# 50976  2013                     Level 3                 ZZ11
# 50977  2013                     Level 3                 ZZ11
# 50978  2013                     Level 3                 ZZ11
# 50979  2013                     Level 3                 ZZ11
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 50975  Food product manufacturing  Dollars (millions)           H32
# 50976  Food product manufacturing  Dollars (millions)           H33
# 50977  Food product manufacturing             Dollars           H34
# ...

# %%
# dtypes function is used to show the data type of the colum, or head

df.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
# calculating mean,std(standard deviation, min, max,total data etc)
df.describe()
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000

# %%
df[["Year","Industry_name_NZSIOC","Units","Variable_name"]]
# Out:
#        Year        Industry_name_NZSIOC               Units  \
# 0      2023              All industries  Dollars (millions)
# 1      2023              All industries  Dollars (millions)
# 2      2023              All industries  Dollars (millions)
# 3      2023              All industries  Dollars (millions)
# 4      2023              All industries  Dollars (millions)
# ...     ...                         ...                 ...
# 50980  2013  Food product manufacturing          Percentage
# 50981  2013  Food product manufacturing          Percentage
# 50982  2013  Food product manufacturing          Percentage
# 50983  2013  Food product manufacturing          Percentage
# 50984  2013  Food product manufacturing          Percentage
#
#                                          Variable_name
# 0                                         Total income
# 1      Sales, government funding, grants and subsidies
# 2                    Interest, dividends and donations
# ...

# %%
# showing all the columns
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
# showing a specific column
df[["Industry_name_NZSIOC"]]
# Out:
#              Industry_name_NZSIOC
# 0                  All industries
# 1                  All industries
# 2                  All industries
# 3                  All industries
# 4                  All industries
# ...                           ...
# 50980  Food product manufacturing
# 50981  Food product manufacturing
# 50982  Food product manufacturing
# 50983  Food product manufacturing
# 50984  Food product manufacturing
#
# [50985 rows x 1 columns]

# %%
# slicing the data
df[["Industry_name_NZSIOC"]][5:21] # here the data is showing from 5 to 20 index
# Out:
#    Industry_name_NZSIOC
# 5        All industries
# 6        All industries
# 7        All industries
# 8        All industries
# 9        All industries
# 10       All industries
# 11       All industries
# 12       All industries
# 13       All industries
# 14       All industries
# 15       All industries
# 16       All industries
# 17       All industries
# 18       All industries
# 19       All industries
# 20       All industries

# %%
# creating a new column with values

df["new_col"] =0

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
#creating a column in a specific position

df.insert(loc = 2, column = "new_info", value=5)

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC  new_info Industry_code_NZSIOC  \
# 0      2023                     Level 1         5                99999
# 1      2023                     Level 1         5                99999
# 2      2023                     Level 1         5                99999
# 3      2023                     Level 1         5                99999
# 4      2023                     Level 1         5                99999
# ...     ...                         ...       ...                  ...
# 50980  2013                     Level 3         5                 ZZ11
# 50981  2013                     Level 3         5                 ZZ11
# 50982  2013                     Level 3         5                 ZZ11
# 50983  2013                     Level 3         5                 ZZ11
# 50984  2013                     Level 3         5                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# ...
